# %% [markdown]
# ## **PROJECT TITLE  ---- TRAVEL AGGREGATOR ANALYSIS**

# %% [markdown]
# Contribution : **Individual**
#
# Name:  **Mythily Arunprasad**

# %% [markdown]
# # **Project Summary.**
#
# A new Indian start-up, **"MyNextBooking”** is an aggregator on top of the available top platforms (Yatra, MMT, Goibibo).The project **"Travel Aggregator Analysis"**  involves analyzing booking data from a travel platform  named " MyNextBooking" with the **goal of understanding user behavior, device usage patterns, and trends over time**.
#
# This data analysis project centers around **booking, searching, and user behavior** on the travel platform **"MyNextBooking"**. The analysis explores multiple dimensions, including:
# 1.	**Booking-to-Search Ratio (OBSR):** The project calculates and visualizes the **OBSR** for various time periods, such as monthly and weekly, to understand the effectiveness of searches converting into bookings. By comparing bookings to searches, the analysis provides insight into user intent and platform performance.
# 2.	**Trends in Bookings by Device Type:** The project examines identifying  quarterly booking trends along with identifying which devices are prefered frequently for booking (e.g., Tablet, desktop,Android, IOS, Mobile web) are more commonly used for bookings nowadays. This allows for identifying shifts in user preferences and platform usage patterns across different quarters of the year.
# 3.	**Time Series Analysis:**	Time series analysis is used to detect any seasonal trends or cyclical behaviors in the booking data. By aggregating the data quarterly and yearly , the project provides an overview of how the number of bookings changes over time and by different device types.
#
# 4.	**Device Type Insights:** The analysis investigates which device types are most commonly used for bookings across different times of the year. By understanding device preferences, the project can highlight areas where the platform can improve to make the user experience better for those devices.
#
# 5.	**Visualization:**    Several visualizations, including time series plots, pie charts, and heatmaps, are used to communicate trends and insights clearly. These visualizations help stakeholders understand the data patterns, such as which days of the week have the highest number of bookings or which device is most used for a particular service.

# %% [markdown]
# ## **Problem Statements:**
#
# 1)	Find the number of distinct bookings,sessions,and searches from the given data sets?
#
# 2)	How many sessions have more than one booking?
#
#
# 3)	Which days of the week have the highest number of bookings?Also,draw a pie chart to show the distribution for all days of the week?
#
# 4)	For each of the service names,display the total number of bookings and the total GrossBooking Value in INR.
#
# 5)	For customers who have more than 1booking, which is the most booked route (from_city to to_city)?
#
# 6)	Which are the top 3 departure cities from where customers bookmostly in advance, provided that there have been at least 5 departures from that city?
#
#
# 7)	Plot a heatmap displaying correlations of the numerical column and report which pair of numerical columns in the bookings dataset,have the maximum correlation?
#
#
# 8)	For each service, which is the most used device type for making bookings on the platform?
#
#
# 9)	Plot the trends at a quarterly frequency for the number of bookings by each of the device types,that is, plot a time series for each year and quarter showing the number of bookings performed by each device type.
#
#
# 10) Consider the following example :12 customers performed a total of 100 searches but only a few of them performed 10 bookings in total.Searches =100, bookings=10 customers=12.The overall booking to search ratio, Obsr is 10/100=0.Using the above information/content,answer the following:
#
# 1.What is the Average Obsr for each month of the year?
#
# 2.What is the Average Obsr for each day of the week?
#
# 3.Plot a time series of Obsr on the given datasets.

# %% [markdown]
# # **Libraries Used :**
#
#
# *  **Pandas (pd)** is used  for handling and analyzing data mostly for
#  **data manipulation and analysis**..
# *   **Seaborn (sns)** is  used for creating **statistical visualizations**.
# *   **Matplotlib (plt)** is used for creating **customizable plots**.
#
# *  Python's **datetime module** includes datetime, date, and time which is used for **handling date and time data.**
#
#
# Importing these tools is crucial for any data science or analytics workflow, as they **provide powerful capabilities for data manipulation, statistical analysis, and time-series operations, enabling efficient data processing and insightful visualizations.**

# %% [markdown]
# **DataSet Includes:**
#
# 1.  Bookings.csv
# 2.  Sessions.csv.
#
# The above files  contain various columns with data related to customer bookings and sessions.
#
# **Description of the columns(key terms) in** **Bookings.csv**
#
#
# **1. customer_id** ---> This indicates the unique identifier for each customer making a booking.
#
# **2. booking_id** --->This indicates the  unique identifier for each booking made.
#
# **3. from_city & from_country** --->This indicates the city & country from which the customer is starting their journey.
#
# **4. to_city & to_country** --->This indicates the destination city & country  where the customer is traveling.
#
# **5. booking_time**---> This indicates the timestamp of when the booking was made.
#
#   **Usage**: Useful for analyzing trends over time (e.g., peak booking times, monthly or seasonal trends).
#
# **6. device_type_used-**--> This indicates the type of device (e.g., mobile, desktop, tablet) used to make the booking.
#
#   **Usage:** This helps to analyze which devices are most commonly used for making bookings.
#
# **7. INR_Amount** --->This indicates the amount of money in Indian Rupees (INR) spent for the booking.
#
# **8. service_name-**--> This indicates the name of the service associated with the booking (Yatra, MMT, Goibibo.).
#
# **9. no_of_passengers**---> This indicates the  number of passengers associated with the booking.
#
# **Usage:** Useful for analyzing group bookings or demand for services based on passenger count
#
# **10. days_to_departure:**---> This indicated the number of days between the booking time and the actual departure date.
#
# **Usage**: This column helps analyze how far in advance customers are making their bookings.
#
# **11. distance_km:**---> The distance (in kilometers) between the from_city and to_city.
#
#
#
# **Description of the key terms   in** **Sessions.csv**
#
#  **1. session_id**--->This indicates a unique identifier for each session started by a customer on the platform.
#
#  **Usage:** Used to track the activity within a single session and associate it with other actions (like searches, bookings).
#
# **2. search_id**--->This indicates a unique identifier for each search performed during a session.
#
# **Usage:** Helps to track and link specific searches with a particular session, useful for analyzing search patterns.
#
# **3. search_time**---> This indicates the timestamp of when a particular search was performed within the session.
#
# **Usage:** Helps to analyze when customers are searching for services and how it relates to their booking behavior.
#
# 4.**session_starting_time**  --->The timestamp when the session started.
#
# **Usage:** Useful for determining how long customers spend on the platform, as well as analyzing peak times for session activity.
#
# **5. booking_id**--->This indicates a  unique identifier of the booking made during the session.
#
# **Usage:** Links the session data to the actual booking, helping to track which sessions resulted in a successful booking and allowing analysis of session-to-booking conversion rates.

# %% [markdown]
# # **Loading the Bookings Dataset**

# %%
import numpy as np
import pandas as pd

##### INPUT STARTS#####

bookingFname = 'Bookings.csv'
sessionFname = 'Sessions.csv'

##### INPUT ENDS#####

bookingdata=pd.read_csv('Bookings.csv')
bookingdata
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %% [markdown]
# # **Loading the Sessions Dataset**

# %%
sessiondata=pd.read_csv('Sessions.csv')
sessiondata
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z          NaN
# 1         2020-01-21T21:10:12Z          NaN
# 2         2020-01-21T21:10:12Z          NaN
# 3         2020-01-21T21:10:12Z          NaN
# 4         2020-01-21T21:10:12Z          NaN
# ...

# %% [markdown]
# # **Data Exploration:**
#
#    Data Exploration is the initial step in understanding the dataset and it involves identifying the structure, content, and types of variables in the data. Identifying Data Types (numerical, categorical, etc.) is a critical part of EDA.This helps you to plan further analysis, visualizations, and cleaning.

# %%
import pandas as pd

# Load dataset (example)

bookingFname = 'Bookings.csv'
sessionFname = 'Sessions.csv'


bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

# Find numerical columns and categorical columns for Bookings Dataset (int or float types)
numerical_data1 = bookingdata.select_dtypes(include=['number'])
categorical_data1 = bookingdata.select_dtypes(include=['object', 'category'])

# Display numerical and categorical columns  for Bookings Dataset:

print("Numerical columns:\n", numerical_data1.columns)
print("\nCategorical columns:\n", categorical_data1.columns)
# Out:
# Numerical columns:
#  Index(['INR_Amount', 'no_of_passengers', 'days_to_departure', 'distance_km'], dtype='object')
#
# Categorical columns:
#  Index(['customer_id', 'booking_id', 'from_city', 'from_country', 'to_city',
#        'to_country', 'booking_time', 'device_type_used', 'service_name'],
#       dtype='object')

# %% [markdown]
# So in Bookings csv file -- **'INR_Amount', 'no_of_passengers', 'days_to_departure', 'distance_km'** comes under **Numerical variable cateory** .
# This Numerical variable classification is used in question no 7 where we plot  a heatmap based on numerical column.

# %% [markdown]
# So in Bookings csv file -- **'customer_id', 'booking_id', 'from_city', 'from_country', 'to_city', 'to_country', 'booking_time', 'device_type_used', 'service_name'** comes under **Categorical variable category.**

# %% [markdown]
# # **Data Cleaning:**
#
# As a part of Data cleaning, we ensure that  the data is being loaded properly.
# It involves identifying and handling issues such as missing values, duplicates, incorrect data types, or inconsistent formatting.
#
# **Data Availability Check:**
#
# **len () function**  is used to perform  this task.
#
# **len(bookingdata)** checks the number of rows in the bookingdata DataFrame.
# If the length is less than or equal to 0 (i.e., the DataFrame is empty), it prints the message: "Data's not available : bookingData Bookings.csv".
#
# Similarly, **len(sessiondata)** checks the number of rows in the sessiondata DataFrame, and if empty, it prints the message: "Datas not available : SessionData Sessions.csv".

# %% [markdown]
# 1. Find the number of distinct bookings,sessions and searches from the given datasets.

# %%
import numpy as np
import pandas as pd


#### Inputs Start ####

bookingFname = 'Bookings.csv'
sessionFname = 'Sessions.csv'

#### Inputs End ####

import numpy as np
import pandas as pd

bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

if len(bookingdata)<=0:
    print("Datas not available : bookingData" , bookingFname)

if len(sessiondata)<=0:
    print("Datas not available : SessionData" , sessionFname)

# nunique () function  will return an integer that tells you how many distinct values a column contains.

#To get count on  unique Booking ID - we apply nunique() function to booking_id column in Bookings Csv file
unique_bookings = bookingdata['booking_id'].nunique()
print(f"Unique Booking IDs: {unique_bookings}")

# To get count on  unique Session ID - we apply nunique() function to session_id column in Sessions Csv file
unique_sessions = sessiondata['session_id'].nunique()
print(f"Unique Session IDs: {unique_sessions}")

# Count the unique search IDs.To get count on  unique Search ID - we apply nunique() function to search_id column in Sessions Csv file
unique_searches = sessiondata['search_id'].nunique()
print(f"Unique Search IDs: {unique_searches}")
# Out:
# Unique Booking IDs: 339
# Unique Session IDs: 331
# Unique Search IDs: 1360

# %% [markdown]
# # **Observation**:
# **1.len() function :**
#
# This code uses the **len()** function to check for empty entries in the DataFrames Booking data and Sessiondata. It verifies whether either of the DataFrames contains no rows. Since no empty data is detected, the function does not return any value.
#
# 2.**nunique()** function is used to count the unique non-null entries in a column.
# This process provides useful insights into how many unique IDs are present in different columns, which can be helpful for identifying duplicates or accessing the diversity of data in the CSV files.
# As a result we get the Data of Unique Booking IDs , Session IDs and Search IDs

# %% [markdown]
# 2.How many sessions have more than one booking?

# %%
import matplotlib.pyplot as plt


bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

# Grouping the session_id and booking_id by groupby () function  and checking  unique booking using nunique() function
# groupbysyntax---groupby()[].functionname()
bookingcounts = sessiondata.groupby('session_id')['booking_id'].nunique()

# Filtering  session_ids which has more than 1 booking
multiplebookings = bookingcounts[bookingcounts > 1]
print(multiplebookings)

#Total count of multiple_bookings
TotalCount = len(multiplebookings)

print(f"Total count of Multiple Bookings: {TotalCount}")
# Out:
# session_id
# session_134    2
# session_154    2
# session_196    2
# session_231    2
# session_27     2
# session_290    2
# session_298    2
# session_324    2
# session_50     2
# session_76     2
# Name: booking_id, dtype: int64
# Total count of Multiple Bookings: 10

# %% [markdown]
# # **Observation:**
# 1.This code analyzes the session data and booking data from Session CSV files.
#
# 2.It groups the session data with booking id and counts how many unique
# bookings there are for each session.
#
# 3.Later filters the sessions with more than one unique booking.
#
# 4.Prints the sessions with multiple bookings and displays the total count of such sessions.

# %% [markdown]
# # **Data Visualization using Pie Chart:**
#
# Data visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, data visualization tools help to simplify complex data and provide insights in a more accessible and understandable format.
#
# **PIE CHART:**
#
# Pie chart is used to visualize how the bookings are distributed across different days of the week, making it easy to see which day has the highest share of bookings.

# %% [markdown]
# 3. which days of the week have the highest number of booking?
# Also draw a pie chart to show the distribution for all days of the week?

# %%
import pandas as pd
import matplotlib.pyplot as plt


bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

# Converting the booking_time to datetime format using to_datetime () function which converts
#a column or a series of date/time values into datetime objects.

bookingdata['booking_time'] = pd.to_datetime(bookingdata['booking_time'], format='%Y-%m-%dT%H:%M:%SZ')
#print(bookingdata)

# from the converted boooking time we need to extract the days of the week using dt.day_name() function.
bookingdata['booking_day'] = bookingdata['booking_time'].dt.day_name()
#print(bookingdata)
# To get each days booking count use value_counts()
booking_day_summary = bookingdata['booking_day'].value_counts()
print(booking_day_summary)
# Inorder to find the day which has the highest number of bookings- use idxmax()function
highest_booking_day = booking_day_summary.idxmax()
highest_booking_count = booking_day_summary.max()

print(f"The day with the highest number of bookings is {highest_booking_day} with {highest_booking_count} bookings.")

# Using Pie chart to display the distributio of bookings for all days of the week
plt.figure(figsize=(8, 6))
plt.pie(booking_day_summary, labels=booking_day_summary.index, autopct='%1.3f%%', startangle=100, colors=plt.cm.Set3.colors)
plt.title('Booking Distribution by Day of the Week')
plt.show()
# Out:
# booking_day
# Thursday     65
# Tuesday      59
# Monday       51
# Friday       51
# Saturday     44
# Sunday       35
# Wednesday    34
# Name: count, dtype: int64
# The day with the highest number of bookings is Thursday with 65 bookings.

# %% [markdown]
# **Observation:**
#
# **Datetime Conversion:**
#
# The booking_time column in bookingdata is being converted to a datetime object using pd.to_datetime() with the specified format '%Y-%m-%dT%H:%M:%SZ'. This is crucial as it standardizes date-time data for easy manipulation.
#
# **Extracting the Day of the Week:**
#
# The day of the week is extracted from the booking_time using the .dt.day_name() function, which converts the datetime objects into the full day names (e.g., 'Monday', 'Tuesday') and stores them in a new column, booking_day.
#
# **Counting Bookings per Day:**
#
# value_counts() function is used  to count the occurrences of each day in the booking_day column. This method provides a frequency count of each day.
#
# **Identifying the Day with the Highest Bookings:**
#
# idxmax()  function is used to find the day with the highest booking count, and max() gives the actual number of bookings for that day.
#
# **Visualizing with a Pie Chart:**
#
# Creating a pie chart to show the distribution of bookings across the days of the week. plt.pie() is used to create the chart, where autopct='%1.3f%%' formats the percentage display to three decimal places, and colors=plt.cm.Set3.colors specifies the color scheme.
#
# **Summary of the Appealing PIE Chart:**
#
# The textual output (e.g., The day with the highest number of bookings is Saturday with 250 bookings) gives concrete information about the peak day.
#
# The pie chart visually reinforces this by displaying the booking distribution in a way that's intuitive and easy to compare.

# %% [markdown]
# 4. For each of the service names, display the total number of bookings
# and the total gross booking value in INR.

# %%
# Group by service name and count bookings
import pandas as pd

bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

booking_counts = bookingdata.groupby('service_name')['booking_id'].count()

# Calculate the total Gross Booking Value (sum of INR_Amount)
gross_booking_value = bookingdata.groupby('service_name')['INR_Amount'].sum()

# Combine the results into a DataFrame
result_df = pd.DataFrame({
    'Total Bookings': booking_counts,
    'Total Gross Booking Value (INR)': gross_booking_value
})

# Display the result
print(result_df)
# Out:
#               Total Bookings  Total Gross Booking Value (INR)
# service_name
# GOIBIBO                  186                       5897637.97
# MMT                       48                        665669.08
# YATRA                    105                       3378702.13

# %% [markdown]
# # **Observation:**
#  1.Calculating Total bookings, using the groupby() function to  group the booking data along with the  service_name(GOIBIO, MMT,YATRA) which displays the required result.
#
#  2.Calculating total Gross Booking Value by grouping service_name and sum of INR_Amount.
#
#  **Output:**
#
#  Execution of the above code correctly calculates and presents the total number of bookings and Gross Booking Value for each service in a clear and organized manner.

# %% [markdown]
# 5. For customers who have more than 1 booking, which is the most booked route(from_city to to_city)?

# %%
import pandas as pd
bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)


# Grouping the booking id for each customers and then counting them using groupby ()function.

bookingcount = bookingdata.groupby('customer_id')['booking_id'].count()

# After grouping evaluting the customers who have more than 1 booking

multiplebooking = bookingcount[bookingcount > 1]


# Get the bookings for multi-booking customers
#isin () function is a very handy function for filtering data.
#This keeps rows where the customer_id is in the list of multi-booking customers.

multiplebooking = bookingdata[bookingdata['customer_id'].isin(multiplebooking.index)]

# To find the most booked route (from_city to to_city) and also to find the count of the  bookings.
routecounts = multiplebooking.groupby(['from_city', 'to_city'])['booking_id'].count()
print(routecounts)

# Find the most booked route. idxmax() finds the route (index) with the highest count.

most_booked_route = routecounts.idxmax()
print(f"Most booked route: {most_booked_route}")
# Out:
# from_city           to_city
# Ahmedabad           Gwalior              1
# Barelā              Gurgaon              1
# Bhubaneswar         Durlaga              1
# Bikaner             Gurgaon              1
# Bālāpur             Düsseldorf           2
# Delhi               Jammu                1
#                     Paris                1
#                     Varanasi             1
#                     Yol                  1
# Devanhalli          Gurgaon              2
# Dharamsala          Gurgaon              1
# Durlaga             Bhubaneswar          2
# Gurgaon             Bagdogra             2
#                     Barelā               1
#                     Berlin               1
#                     Bhubaneswar          2
#                     Birmingham           1
#                     Dharamsala           1
#                     Fiumicino            1
#                     Frankfurt am Main    1
#                     Hamburg              1
# ...

# %% [markdown]
# **Observation:**
#
# Above code correctly identifies the most popular frequently booked route among repeated customers as('Gurgaon', 'Roissy-en-France').
#
# **Result:**
#
#  These codings provides valuable insights into customer behavior, route preferences, and business opportunities by identifying the most frequently booked routes for repeated customers. Based on the result obtained, it  can **help businesses focus their efforts on marketing, pricing, and resource allocation for that specific route**.

# %% [markdown]
# 6.Which are top 3 departure cities from where customers book mostly in advance, provided that there have been atleast 5 departures from that city?

# %%
import pandas as pd

bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)


# Using from_city and booking id , we get the count of departures using groupby () function
departure_counts = bookingdata.groupby('from_city')['booking_id'].count()

# get the list of departures which is >=5
frequent_departure = departure_counts[departure_counts >= 5]
print(frequent_departure)

# Sorting the  departure count in asscending order by applying false to ascending tag using sort_values
sorted_departures = frequent_departure.sort_values(ascending=False)

# We get the top 3 departure cities using indexing.
top3_cities = sorted_departures.index[:3]

print(f"Top 3 departure cities for advance bookings: {', '.join(top3_cities)}")
# Out:
# from_city
# Ahmedabad        8
# Bālāpur          6
# Chennai         16
# Delhi           29
# Devanhalli      24
# Gurgaon        136
# Madhyamgram      6
# Mumbai          34
# New Delhi        7
# Rāja Sānsi      17
# Name: booking_id, dtype: int64
# Top 3 departure cities for advance bookings: Gurgaon, Mumbai, Delhi

# %% [markdown]
# **Observation:**
#
# **Cities with Adequate Departures:**
#
# The frequent_departure variable successfully filters out cities that have fewer than 5 departures.
#
# By sorting the frequent_departure data in descending order, we identify the cities with the highest number of departures. This provides a clear ranking of cities based on their booking frequency.
#
# **Top 3 Cities:**
#
# The final output gives the top 3 departure cities with the highest number of departures, after ensuring that each of these cities has had at least 5 departures.
#
# **Results: Gurgaon, Mumbai, Delhi**

# %% [markdown]
# # **Data visualization using Heat Map:**
#
# A **heatmap** is a data visualization tool that uses color gradients to represent the **magnitude of values in a matrix or table**. It is typically used to **display correlations, patterns, or the intensity of data across two dimensions.**

# %% [markdown]
# 7. Plot  a HeatMap Displaying Correlations of the numerical column and report which pair of numerical columns in the bookings dataset, have the maximum correlation?

# %%
import seaborn as sns

bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)
#we need select numerical columns for displaying correlations.
NumericalColumn =  bookingdata.select_dtypes(include=['number'])
print(NumericalColumn)

#Calculating the Correlation Matrix ( correlation matrix, where each element represents the correlation between two variables (columns))
correlation_matrix = NumericalColumn.corr()
print(correlation_matrix)

# creating a heatmap using correlation matrix to find report which pair
#of numerical columns in the bookings dataset, have the maximum correlation.

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt=".1f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
#      INR_Amount  no_of_passengers  days_to_departure  distance_km
# 0       2565.28                 1                 10        747.8
# 1      23120.00                 1                  1       6701.5
# 2      25717.60                 1                 32       7712.0
# 3     135969.60                 2                 69       6112.5
# 4      31791.20                 1                  3       6570.4
# ..          ...               ...                ...          ...
# 334     2721.60                 1                 26        421.0
# 335     6552.00                 1                  0       1274.7
# 336   126502.46                 2                109       7190.9
# 337    55152.80                 2                 22       6760.0
# 338    41117.60                 1                 20       6354.9
#
# [339 rows x 4 columns]
#                    INR_Amount  no_of_passengers  days_to_departure  \
# INR_Amount           1.000000          0.397229           0.284534
# ...

# %% [markdown]
# # **Observation:**
#
# "Using a heatmap, a popular and effective data visualization tool, we can easily interpret the correlation matrix. It allows us to quickly identify and understand the relationships between different variables, such as the strength and direction of their associations. This visual representation simplifies the process of analyzing complex datasets, helping us make informed decisions and draw meaningful insights."
#
# 1.**Booking Amount (INR_Amount) and Distance (distance_km)** have the **strongest correlation** (0.623565), which is expected, as longer trips tend to have higher costs.
#
# 2**.Booking Amount (INR_Amount) and Number of Passengers (no_of_passengers)** also show a **moderate correlation** (0.397229), indicating that larger groups typically result in higher total booking amounts.
#
# 3.**Days to Departure (days_to_departure) and Booking Amount (INR_Amount)** show a **weak positive correlation** (0.284534), suggesting that there may be slight trends where longer lead-time bookings involve larger amounts, but the relationship is not strong.
#
# 4.**No strong correlation** between **Number of Passengers (no_of_passengers) and Distance Traveled (distance_km)** (0.001698), meaning that the size of the group doesn’t seem to affect how far they travel.

# %% [markdown]
# # **Exploratory Data Analysis(EDA)**
# Categorical Data Analysis and Device Usage Analysis Phase:**
#
# This phase specifically focusing on categorical data analysis to identify the most commonly used devices for booking services on the platform. It provides valuable insights into user behavior and can guide decisions in terms of platform optimization and marketing.

# %% [markdown]
# 8.For each service, which is the most used device type for making bookings on the platform?

# %%
# Group by service name and count device types
import pandas as pd


bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

# Grouping the service name and device type using group() function.
#value_counts(): This function count is used to tell us how many times each device_type_used occurs.
device_counts = bookingdata.groupby('service_name')['device_type_used'].value_counts()
print(device_counts)

# Get the most used device type for each service by idxmax() function
most_used_devices = device_counts.groupby('service_name').idxmax()
print(most_used_devices)

print("Most used device type for each service:")
# items() method returns an iterable of key-value pairs and Prints the current service and its corresponding device.

for service , device in most_used_devices.items():
  print(f"{service}: {device[1]}")
# Out:
# service_name  device_type_used
# GOIBIBO       IOS                 70
#               Desktop             61
#               Android             44
#               MobileWeb           11
# MMT           Desktop             30
#               Android              8
#               IOS                  5
#               MobileWeb            5
# YATRA         Desktop             51
#               IOS                 22
#               Android             18
#               MobileWeb           11
#               Tablet               3
# Name: count, dtype: int64
# service_name
# GOIBIBO      (GOIBIBO, IOS)
# MMT          (MMT, Desktop)
# YATRA      (YATRA, Desktop)
# Name: count, dtype: object
# Most used device type for each service:
# GOIBIBO: IOS
# MMT: Desktop
# YATRA: Desktop

# %% [markdown]
# # **Observation:**
#
# Based on the EDA, the most used device types for making bookings on the platform for each service are as follows:
#
# **GOIBIBO:**
#
# The most used device for bookings is **IOS**, with a total of **70 bookings.**
# This suggests that IOS devices (iPhones and iPads) are the preferred choice for users booking services on GOIBIBO.
#
# **MMT (MakeMyTrip):**
#
# The most used device for bookings  is  **Desktop**, with **30 bookings**.
# This indicates that desktop computers are the most commonly used device for making bookings on MMT, which might reflect the nature of the customers (e.g., business users or users preferring a larger screen).
#
# **YATRA:**
#
# The most used device for bookings is **Desktop**, with **51 bookings**.
# Similar to MMT, desktop usage is dominant on YATRA, which might suggest a trend toward users preferring to make bookings from a desktop computer.

# %% [markdown]
# 9. Plot the trends at a quarterly frequency for the number of bookings by each of the device types,that is, plot a time series for each year and quarter showing the number of bookings performed by each device type.

# %% [markdown]
# # **Time Series Plot:**
#
# A time series plot is a **graphical representation of data points** in a time sequence. It is used to **visualize trends, patterns, or fluctuations over time**.It is an essential tool in data analysis, e**nabling better decision-making by offering a clear visualization of how variables change over time and providing insights into future behavior**.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, date, time

bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

# Convert booking_time to datetime(pd.to_datetime() is a function in the pandas library
#that is used to convert a variety of date and time formats into datetime objects.
#This is especially useful when working with time-series data,
#as it enables easier manipulation and extraction of time-based components like year, month, day, etc.

#to_datetime() function converts the booking_time column to a pandas datetime object
#to enable operations like extracting year and quarter.
bookingdata['booking_time'] = pd.to_datetime(bookingdata['booking_time'])
#print(bookingdata)

# Extracting year using dt.year and quarter using dt.quarter.
#dt.year is a pandas accessor used to extract the year from a datetime object in a pandas DataFrame)
bookingdata['year'] = bookingdata['booking_time'].dt.year
#dt.quarter is a pandas accessor that extracts the quarter of the year from a datetime object.
#The quarter of the year is a number between 1 and 4.
bookingdata['quarter'] = bookingdata['booking_time'].dt.quarter

# Group by year, quarter, and device type
booking_counts = bookingdata.groupby(['year', 'quarter', 'device_type_used']).size().reset_index(name='count')


# Create time series plots
plt.figure(figsize=(8, 6))
sns.lineplot(x='quarter', y='count', hue='device_type_used', data=booking_counts)
plt.xlabel('Quarter')
plt.ylabel('Number of Bookings')
plt.title('Quarterly Booking performed by Each Device Type')
plt.grid(True)
plt.show()

# Create time series plots
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='count', hue='device_type_used', data=booking_counts)
plt.xlabel('year')
plt.ylabel('Number of Bookings')
plt.title('Yearly Booking Performed by Each Device Type')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Observation:**
#
# **Seasonal Trends:**
#
# By analyzing the trends over multiple quarters, we might observe certain devices being used more frequently during specific periods of the year, suggesting seasonal patterns.
#
# **Platform Growth:**
#
# A gradual rise or fall in bookings by device type can reveal insights into platform growth and user preferences.
#
# **Platform Optimization:**
#
# A decline in usage for certain platforms, like MobileWeb or Android, could point to issues with the user experience or a shift toward other platforms (e.g., mobile apps).
#
# **Conclusion:**
#
# By analyzing the quarterly and yearly trends of bookings per device type, we gain valuable insights into changing user preferences, seasonal variations, and emerging patterns. These insights can help identify shifts in user behavior and guide platform development and marketing strategies.

# %% [markdown]
# 1O. consider the following example :12 customers performed a total of 100 searches but only a few of them performed 10 bookings in total.
# Searches =100, bookings=10 customers=12.The overall booking to search ratio, Obsr is 10/100=0.1 .Using the above information/content,answer the following:
#
# 1.What is the Average Obsr for each month of the year?
#
# 2.What is the Average Obsr for each day of the week?
#
# 3.Plot a time series of Obsr on the given datasets.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the sessions.csv file (replace 'C:\\sessions.csv' with the actual file path)


bookingdata=pd.read_csv(bookingFname)
sessiondata=pd.read_csv(sessionFname)

# Convert the 'search_time' column to datetime
# use mixed as option in the format if u r unsure about the pattern like YY/MM/DD

sessiondata['search_time'] = pd.to_datetime(sessiondata['search_time'], format='mixed', errors='coerce')
bookingdata['booking_time'] = pd.to_datetime(bookingdata['booking_time'], format='mixed', errors='coerce')
#print(sessiondata)

# Extract year and month
sessiondata['year'] = sessiondata['search_time'].dt.year
sessiondata['month'] = sessiondata['search_time'].dt.month

bookingdata['year'] = bookingdata['booking_time'].dt.year
bookingdata['month'] = bookingdata['booking_time'].dt.month

#search_counts = sessiondata.groupby(['year', 'month'])['search_id'].nunique().reset_index(name='total_searches')


# Calculate the total searches and bookings
total_searches = sessiondata['search_id'].nunique()
total_bookings = bookingdata['booking_id'].nunique()

# Calculate the overall booking to search ratio (OBSR)
OBSR = total_bookings / total_searches

print(f"Overall booking to search ratio (OBSR): {OBSR:.2f}")

# Calculate the average oBSR for each month
average_OBSR_monthly = bookingdata.groupby(['year', 'month'])['booking_id'].nunique() / sessiondata.groupby(['year', 'month'])['search_id'].nunique()

print("Average OBSR for each month:")
print(average_OBSR_monthly)

# Calculate the average oBSR for each day of the week
bookingdata['day_of_week'] = bookingdata['booking_time'].dt.dayofweek
sessiondata['day_of_week'] = sessiondata['search_time'].dt.dayofweek
average_OBSR_daily = bookingdata.groupby('day_of_week')['booking_id'].nunique() / sessiondata.groupby('day_of_week')['search_id'].nunique()

print("Average OBSR for each day of the week:")
print(average_OBSR_daily)
# Out:
# Overall booking to search ratio (OBSR): 0.25
# Average OBSR for each month:
# year  month
# 2018  9        0.387097
#       10       0.095238
#       11       0.243902
#       12       0.193548
# 2019  1        0.333333
#       6        1.000000
#       7        0.217391
#       8        0.285714
#       9        0.304348
#       10       0.214286
#       11       0.285714
#       12       0.228070
# 2020  1        0.226027
#       2        0.306452
#       3        0.300000
#       5        0.111111
#       6        0.333333
#       7        0.100000
#       8        0.666667
#       9        0.375000
#       10       0.545455
#       11       0.407407
#       12       0.666667
# 2021  1        0.571429
#       2        0.363636
#       3        0.312500
#       4        0.258065
#       5        0.500000
#       6        0.428571
#       7        0.117647
#       8        0.210526
#       9        0.521739
#       10       0.300000
#       11       0.147059
# ...

# %% [markdown]
# # **OBSERVATION:**
#
# **Overall OBSR:** Displays the overall ratio of bookings to searches for all the data combined.
#
# 0.25 is the overall ratio of bookings to searches across all time periods. This means that, on average, 25% of searches result in bookings.
#
# **Average OBSR by Month:**  Shows the average OBSR for each month, helping you understand how the booking/search behavior changes throughout the year.
#
# The OBSR fluctuates significantly throughout the months of each year. This suggests seasonal or periodic changes in user behavior, which could be tied to factors such as promotions, holidays, or market conditions.
# Some months have very high OBSR values (like June 2019 with 1.000 and December 2020 with 0.666), indicating a higher conversion rate of searches to bookings in those periods.
#
# **Average OBSR by Day of the Week:** Shows the average OBSR for each day of the week, helping to identify patterns like whether bookings tend to occur more on certain days.
#
# Sunday (Day 0) has an OBSR of 0.217.
# Monday (Day 1) has a higher OBSR of 0.292.
# Tuesday (Day 2) shows a lower OBSR of 0.170.
# Wednesday (Day 3) and Thursday (Day 4) have similar ratios (0.245 and 0.297).
# Friday (Day 5) and Saturday (Day 6) show similar ratios (0.247 and 0.324),
# Saturday (Day 6) has the highest average OBSR, indicating that users tend to make more bookings on this day relative to the searches they perform.
# Tuesday (Day 2) has the lowest OBSR, suggesting that search activity on this day doesn’t convert as well to bookings.
#
# **Conclusion:**
#
# **Seasonality and Trends:** The monthly and yearly variations in the OBSR indicate that certain times of the year (e.g., June 2019 and December 2020) have stronger user engagement and conversion rates, while other months show weaker performance. Understanding these patterns can help in predicting when to focus marketing efforts or optimize the user experience on the platform.
#
# **Day of the Week Patterns:** The data also highlights that the day of the week influences the conversion rate. Weekends (especially Saturday) tend to have a higher OBSR, meaning users are more likely to book on those days. On the other hand, weekdays like Tuesday have a lower ratio, suggesting that searches performed on this day are less likely to lead to bookings.
#
# **In conclusion**, leveraging time-based insights from the OBSR analysis can lead to better-aligned marketing strategies, more efficient platform optimization, improved business forecasting, and an enhanced customer experience—ultimately driving sustained business growth.

# %% [markdown]
# # **Summary of Travel Aggregator Analysis Project:**
#
# **Overall Conclusion:**
#
# The data analysis project has provided valuable insights into the relationship between searches and bookings, measured through the Booking to Search Ratio (OBSR), over various time periods. By leveraging Python for data processing and analysis, we have gained a deeper understanding of user behavior patterns, which can directly influence business decisions.
#
# **Key Findings:**
#
# **Overall OBSR:** The OBSR of 0.25 indicates that, on average, only 25% of searches result in bookings across the entire dataset. This suggests opportunities for improving conversion rates.
#
# **Monthly and Seasonal Trends:**
#
# The monthly OBSR data revealed clear fluctuations, with some months like June 2019 and December 2020 showing significantly higher conversion rates. This points to potential seasonal trends that could be leveraged for marketing or operational planning.
#
# The seasonal variations emphasize that businesses should optimize their strategies based on the time of year, with higher OBSR in certain months signaling times of increased user engagement.
#
# **Day-of-Week Patterns:**
#
# Saturdays show the highest average OBSR, indicating that users are more likely to convert their searches into bookings during weekends.
# Tuesdays, on the other hand, demonstrated lower conversion rates, suggesting that businesses might focus on boosting engagement or conversion rates during these quieter days.
#
# **Actionable Insights:**
#
# **Targeted Marketing:** By understanding when users are most likely to book, businesses can optimize marketing campaigns to coincide with high-conversion months and days, thus maximizing ROI.
#
# **Platform Optimization:** High-traffic periods, such as weekends or certain months, should prompt businesses to ensure that their platforms are prepared to handle increased demand.
#
# **Forecasting & Resource Allocation:** Predicting peak periods based on historical OBSR data can help businesses allocate resources more efficiently, preparing for high-demand periods and reducing operational inefficiencies during slower periods.
#
# **Strategic Recommendations:**
#
# 1.Focus on seasonal promotions during months with high OBSR to maximize bookings.
# Optimize user experience and platform performance during peak times (e.g., Saturdays or December).
#
# 2.Use off-peak days (e.g., Tuesdays) to run targeted campaigns or provide incentives to increase conversions.
#
# 3.Continuously monitor the OBSR over time to adapt marketing strategies, platform features, and resource allocation, ensuring business growth and customer satisfaction.
#
# **Final Thought:**
#
# This analysis has provided a comprehensive view of how time-based insights can drive better business decisions. By leveraging these findings, businesses can enhance their customer experience, boost conversion rates, and make data-driven decisions that contribute to long-term growth and success.

# %% [markdown]
# # **Thanks Note to Python:**
#
# I just wanted to take a moment to express my sincere appreciation for the incredible capabilities that **"Python"** provides in the world of data analysis. It's flexibility, power, and vast array of libraries (like pandas, numpy and matplotlib) make data processing, visualization, and modeling more efficient and insightful than ever before.
#
# From cleaning and transforming raw data to generating meaningful visualizations, your straightforward syntax and vast community support have been invaluable. Whether it's calculating complex metrics like Booking to Search Ratio (OBSR), uncovering patterns in time-based data, or automating repetitive tasks, you have truly made the analysis process not only possible but enjoyable.
#
# Thank you for being the backbone of many project **"TRAVEL AGGREGATOR ANALYSIS"** and for empowering analysts like me to transform complex data into valuable, actionable insights.

# %% [markdown]
# # **Thank You for Your Guidance on the Project**
#
# **Dear Anu**,
#
# I would like to sincerely thank you for your invaluable guidance and support throughout the  project "TRAVEL AGGREGATOR ANALYSIS". Your insights, expertise, and patience helped me navigate challenges and approach the project with confidence.
#
# Your constructive feedback and thoughtful suggestions played a crucial role in refining my work and enhancing my understanding of the subject. I truly appreciate the time and effort you dedicated to helping me improve and succeed.
#
# Thank you once again for being such an excellent mentor. I'm grateful for the knowledge I've gained through your support, and I look forward to applying these lessons in future projects.
